# %%
import matplotlib.pyplot as plt
import numpy as np
from backbone.mix_k_dihedral import MixPlot1

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
strand_id = 'STRAND1'
plot_agent = MixPlot1(host, strand_id)

# %% [markdown]
# ### Part 2: Plot

# %%
figsize = (8, 12)
hspace = 0
bottom = 0 
top = 3.4
plot_agent.plot_main(figsize, hspace, bottom, top)
plt.show()

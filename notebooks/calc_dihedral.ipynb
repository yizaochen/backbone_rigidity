# %%
from os import path
from backbone.dihedral import DihedralMaker
import numpy as np
import MDAnalysis as mda
big_traj_folder = '/home/yizaochen/codes/dna_rna/all_systems'
backbone_data_folder = '/home/yizaochen/codes/dna_rna/backbone_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
strand_id = 'STRAND2'
d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2 exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/ndx exists
# mkdir /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/plumed_input
# mkdir /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/plumed_out

# %% [markdown]
# ### Part 2: Set Dihedral Name

# %%
dihedral_name = 'C4prime-P' # 'C2prime-P', 'C4prime-P'

# %% [markdown]
# ### Part 3: Calculate Dihedral by PLUMED

# %%
#d_agent.make_all_out(dihedral_name)

# %% [markdown]
# ### Batch Run

# %%
"""
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
for host in hosts:
    for strand_id in strand_lst:
        d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
        d_agent.make_all_out(dihedral_name)
"""

# %%
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
dihedral_name_lst = ['C1prime-N3orO2', 'C1prime-N7orC5']
for host in hosts:
    for strand_id in strand_lst:
        d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
        for dihedral_name in dihedral_name_lst:
            d_agent.make_all_out_with_resname(dihedral_name)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1 exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/ndx exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out exists
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.4.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.4.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.4.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 105 107 120 119
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out/C1prime-N3orO2.4.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.4.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.640115     0.640115     0.640115     0.640115
# PLUMED: 1 Prepare dependencies                         50001     0.009556     0.000000     0.000000     0.000018
# PLUMED: 2 Sharing data                                 50001     0.136969     0.000003     0.000002     0.005593
# PLUMED: 3 Waiting for data                             50001     0.035883     0.000001     0.000001     0.000024
# PLUMED: 4 Calculating (forward loop)                   50001     0.075916     0.000002     0.000001     0.000030
# PLUMED: 5 Applying (backward loop)                     50001     0.135815     0.000003     0.000003     0.000682
# PLUMED: 6 Update                                       50001     0.096171     0.000002     0.000002     0.000043
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.5.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.5.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.5.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 137 139 152 151
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out/C1prime-N3orO2.5.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N3orO2.5.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.633219     0.633219     0.633219     0.633219
# PLUMED: 1 Prepare dependencies                         50001     0.008197     0.000000     0.000000     0.000025
# PLUMED: 2 Sharing data                                 50001     0.130476     0.000003     0.000002     0.000669
# PLUMED: 3 Waiting for data                             50001     0.036481     0.000001     0.000001     0.000030
# PLUMED: 4 Calculating (forward loop)                   50001     0.073525     0.000001     0.000001     0.000027
# PLUMED: 5 Applying (backward loop)                     50001     0.137754     0.000003     0.000003     0.000029
# PLUMED: 6 Update                                       50001     0.095689     0.000002     0.000002     0.000034
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.4.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.4.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.4.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 105 107 108 110
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out/C1prime-N7orC5.4.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.4.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.619249     0.619249     0.619249     0.619249
# PLUMED: 1 Prepare dependencies                         50001     0.008818     0.000000     0.000000     0.000019
# PLUMED: 2 Sharing data                                 50001     0.128814     0.000003     0.000002     0.000729
# PLUMED: 3 Waiting for data                             50001     0.034886     0.000001     0.000001     0.000029
# PLUMED: 4 Calculating (forward loop)                   50001     0.069125     0.000001     0.000001     0.000029
# PLUMED: 5 Applying (backward loop)                     50001     0.139293     0.000003     0.000003     0.000031
# PLUMED: 6 Update                                       50001     0.090614     0.000002     0.000002     0.000030
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.5.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.5.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/C1prime-N7orC5.5.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_out/C1prime-N3orO2.25.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N3orO2.25.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.645333     0.645333     0.645333     0.645333
# PLUMED: 1 Prepare dependencies                         50001     0.009076     0.000000     0.000000     0.000020
# PLUMED: 2 Sharing data                                 50001     0.132494     0.000003     0.000002     0.000732
# PLUMED: 3 Waiting for data                             50001     0.034864     0.000001     0.000001     0.000032
# PLUMED: 4 Calculating (forward loop)                   50001     0.075333     0.000002     0.000001     0.000034
# PLUMED: 5 Applying (backward loop)                     50001     0.144785     0.000003     0.000003     0.000036
# PLUMED: 6 Update                                       50001     0.097566     0.000002     0.000002     0.000033
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N3orO2.26.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N3orO2.26.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1321
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N3orO2.26.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 797 799 809 810
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_out/C1prime-N3orO2.26.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N3orO2.26.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.630198     0.630198     0.630198     0.630198
# PLUMED: 1 Prepare dependencies                         50001     0.009298     0.000000     0.000000     0.000028
# PLUMED: 2 Sharing data                                 50001     0.126616     0.000003     0.000002     0.000649
# PLUMED: 3 Waiting for data                             50001     0.034498     0.000001     0.000001     0.000015
# PLUMED: 4 Calculating (forward loop)                   50001     0.078699     0.000002     0.000001     0.000020
# PLUMED: 5 Applying (backward loop)                     50001     0.136867     0.000003     0.000003     0.000032
# PLUMED: 6 Update                                       50001     0.096112     0.000002     0.000002     0.000034
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.25.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.25.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1321
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.25.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 764 766 767 769
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_out/C1prime-N7orC5.25.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.25.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.629902     0.629902     0.629902     0.629902
# PLUMED: 1 Prepare dependencies                         50001     0.008082     0.000000     0.000000     0.000016
# PLUMED: 2 Sharing data                                 50001     0.132262     0.000003     0.000002     0.000645
# PLUMED: 3 Waiting for data                             50001     0.034591     0.000001     0.000001     0.000025
# PLUMED: 4 Calculating (forward loop)                   50001     0.070304     0.000001     0.000001     0.000031
# PLUMED: 5 Applying (backward loop)                     50001     0.140627     0.000003     0.000003     0.000031
# PLUMED: 6 Update                                       50001     0.094487     0.000002     0.000002     0.000028
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.26.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.26.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1321
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.26.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 797 799 800 802
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_out/C1prime-N7orC5.26.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/gcgc_21mer/STRAND2/plumed_input/C1prime-N7orC5.26.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup

# %%
from os import path
from backbone.dihedral import DihedralMaker
import numpy as np
import MDAnalysis as mda
big_traj_folder = '/home/yizaochen/codes/dna_rna/all_systems'
backbone_data_folder = '/home/yizaochen/codes/dna_rna/backbone_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
strand_id = 'STRAND2'
d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2 exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/ndx exists
# mkdir /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/plumed_input
# mkdir /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND2/plumed_out

# %% [markdown]
# ### Part 2: Set Dihedral Name

# %%
dihedral_name = 'C4prime-P' # 'C2prime-P', 'C4prime-P'

# %% [markdown]
# ### Part 3: Calculate Dihedral by PLUMED

# %%
#d_agent.make_all_out(dihedral_name)

# %% [markdown]
# ### Batch Run

# %%
"""
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
for host in hosts:
    for strand_id in strand_lst:
        d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
        d_agent.make_all_out(dihedral_name)
"""

# %%
"""
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
dihedral_name_lst = ['C1prime-N3orO2', 'C1prime-N7orC5']
for host in hosts:
    for strand_id in strand_lst:
        d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
        for dihedral_name in dihedral_name_lst:
            d_agent.make_all_out_with_resname(dihedral_name)
"""

# %%
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
dihedral_name_lst = ['O4prime-C4orC2', 'C2prime-C4orC2']
for host in hosts:
    for strand_id in strand_lst:
        d_agent = DihedralMaker(host, strand_id, big_traj_folder, backbone_data_folder)
        for dihedral_name in dihedral_name_lst:
            d_agent.make_all_out_with_resname(dihedral_name)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1 exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/ndx exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input exists
# /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out exists
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.4.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.4.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.4.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 104 105 107 120
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out/O4prime-C4orC2.4.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.4.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.643569     0.643569     0.643569     0.643569
# PLUMED: 1 Prepare dependencies                         50001     0.008886     0.000000     0.000000     0.000017
# PLUMED: 2 Sharing data                                 50001     0.136565     0.000003     0.000002     0.006244
# PLUMED: 3 Waiting for data                             50001     0.035443     0.000001     0.000001     0.000048
# PLUMED: 4 Calculating (forward loop)                   50001     0.074131     0.000001     0.000001     0.000045
# PLUMED: 5 Applying (backward loop)                     50001     0.140923     0.000003     0.000003     0.000052
# PLUMED: 6 Update                                       50001     0.095496     0.000002     0.000002     0.000210
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.5.dat
# plumed driver --plumed /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.5.dat --mf_xtc /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
#
# DRIVER: Found molfile format trajectory xtc with name /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.all.xtc
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.7.2 (git: Unknown) compiled on Jul 28 2021 at 05:38:58
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /home/yizaochen/miniconda3/envs/backbone/lib/plumed
# PLUMED: For installed feature, see /home/yizaochen/miniconda3/envs/backbone/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1342
# PLUMED: File suffix:
# PLUMED: FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.5.dat
# PLUMED: Action TORSION
# PLUMED:   with label phi1
# PLUMED:   between atoms 136 137 139 152
# PLUMED:   using periodic boundary conditions
# PLUMED: Action PRINT
# PLUMED:   with label @1
# PLUMED:   with stride 1
# PLUMED:   with arguments phi1
# PLUMED:   on file /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_out/O4prime-C4orC2.5.out
# PLUMED:   with format  %f
# PLUMED: END FILE: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2.5.dat
# PLUMED: Timestep: 1.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.633576     0.633576     0.633576     0.633576
# PLUMED: 1 Prepare dependencies                         50001     0.008674     0.000000     0.000000     0.000022
# PLUMED: 2 Sharing data                                 50001     0.133280     0.000003     0.000002     0.000655
# PLUMED: 3 Waiting for data                             50001     0.035588     0.000001     0.000001     0.000014
# PLUMED: 4 Calculating (forward loop)                   50001     0.069848     0.000001     0.000001     0.000034
# PLUMED: 5 Applying (backward loop)                     50001     0.141105     0.000003     0.000003     0.000030
# PLUMED: 6 Update                                       50001     0.092825     0.000002     0.000002     0.000038
# Write PLUMED Input: /home/yizaochen/codes/dna_rna/backbone_data/a_tract_21mer/STRAND1/plumed_input/O4prime-C4orC2
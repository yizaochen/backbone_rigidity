# %%
from os import path
import numpy as np
from backbone.rms import RMSFReader, RMSFResPlot
import matplotlib.pyplot as plt
big_traj_folder = '/home/yizaochen/codes/dna_rna/all_systems'
backbone_data_folder = '/home/yizaochen/codes/dna_rna/backbone_data'
drawzone_folder = '/home/yizaochen/Desktop/drawzone_temp'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'g_tract_21mer'
plot_agent = RMSFResPlot(host, big_traj_folder, backbone_data_folder)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer/STRAND1 exists
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer/STRAND1/ndx exists
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer/STRAND2 exists
# /home/yizaochen/codes/dna_rna/backbone_data/g_tract_21mer/STRAND2/ndx exists

# %% [markdown]
# ### Part 2: Test Plot

# %%
figsize = (6, 4)
inverse = True
ylim = (1.2, 3.2)
assisthlines = np.arange(1.25, 3.01, 0.25)

plot_agent.plot_main(figsize, inverse, ylim, assisthlines)
svg_out = path.join(drawzone_folder, f'{host}.svg')
plt.tight_layout()
plt.savefig(svg_out, dpi=150)
plt.show()

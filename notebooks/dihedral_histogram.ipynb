# %%
from os import path
from backbone.dihedral_plot import FourDihedralHistogram
import matplotlib.pyplot as plt
big_traj_folder = '/home/yizaochen/codes/dna_rna/all_systems'
backbone_data_folder = '/home/yizaochen/codes/dna_rna/backbone_data'
drawzone_folder = '/home/yizaochen/Desktop/drawzone_temp'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'atat_21mer'
plot_agent = FourDihedralHistogram(host, big_traj_folder, backbone_data_folder)
# Out:
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND1 exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND1/ndx exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND1/plumed_input exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND1/plumed_out exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND2 exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND2/ndx exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND2/plumed_input exists
# /home/yizaochen/codes/dna_rna/backbone_data/atat_21mer/STRAND2/plumed_out exists

# %% [markdown]
# ### Part 2: Histogram

# %%
figsize = (8, 8)
bins = 180
plot_agent.histogram(figsize, bins=bins)
plt.tight_layout()
svg_out = path.join(drawzone_folder, f'{host}.svg')
plt.savefig(svg_out, dpi=150, transparent=False)
plt.show()
